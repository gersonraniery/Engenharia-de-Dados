# %% [markdown]
# Solucione os problemas propostos abaixo utilizando os conhecimentos adquiridos até aqui.

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
pd.read_csv(url)
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
df_alunos = pd.read_csv(url)

# %% [markdown]
# 1) Verifique se a base de dados possui dados nulos e, caso tenha, realize o tratamento desses dados nulos da forma que achar mais coerente com a situação.

# %%
df_alunos.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       6
# Aprovado    0
# dtype: int64

# %%
df_alunos.fillna(0)
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %%
df_alunos = df_alunos.fillna(0)

# %% [markdown]
# 2) Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados.

# %%
df_alunos.query('Nome == "Alice" | Nome == "Carlos"').index
# Out:
# Int64Index([7, 8], dtype='int64')

# %%
alunos_remover = df_alunos.query('Nome == "Alice" | Nome == "Carlos"').index
df_alunos.drop(alunos_remover, axis=0, inplace=True)
#axis=0 quer dizer linha, se fosse coluna seria axis=1

# %%
df_alunos.query('Nome == "Alice" | Nome == "Carlos"')
# Out:
# Empty DataFrame
# Columns: [Nome, Idade, Notas, Aprovado]
# Index: []

# %% [markdown]
# 3) Aplique um filtro que selecione apenas os alunos que foram aprovados.

# %%
df_alunos['Aprovado'] == True
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6      True
# 9     False
# 10    False
# 11    False
# 12     True
# 13     True
# 14    False
# 15     True
# 16    False
# 17     True
# Name: Aprovado, dtype: bool

# %%
aprovados = df_alunos['Aprovado'] == True
df_alunos[aprovados]
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %%
alunos_aprovados = df_alunos[aprovados]

# %% [markdown]
# 4) Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv".

# %%
alunos_aprovados.to_csv('alunos_aprovados.csv')

# %%
#testando se salvou corretamente
pd.read_csv('alunos_aprovados.csv')
# Out:
#    Unnamed: 0       Nome  Idade  Notas  Aprovado
# 0           0        Ary     20    7.5      True
# 1           4       Beto     21   10.0      True
# 2           6       Dara     21    7.0      True
# 3          12  Sthefanie     26    9.5      True
# 4          13      Mirla     25    9.0      True
# 5          15     Mylena     29    7.0      True
# 6          17      Nadia     34    8.0      True

# %% [markdown]
# Ao conferir as notas dos alunos aprovados, notamos que algumas notas estavam incorretas. As alunas que tiraram nota 7.0, na verdade, tinham um ponto extra que não foi contabilizado. Sendo assim, substitua as notas 7.0 da base de dados por 8.0.

# %%
alunos_aprovados
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %%
alunos_aprovados.replace(7.0, 8.0)
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    8.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    8.0      True
# 17      Nadia     34    8.0      True

# %%
alunos_aprovados = alunos_aprovados.replace(7.0, 8.0)

# %% [markdown]
# Salvando o arquivo

# %%
df_alunos.to_csv('alunos_atualizado.csv', index=False)

# %%
#testando se salvou corretamente
pd.read_csv('alunos_atualizado.csv')
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 7       Vitor     28    0.0     False
# 8      Daniel     21    0.0     False
# 9        Igor     24    4.5     False
# 10  Sthefanie     26    9.5      True
# 11      Mirla     25    9.0      True
# 12      Paulo     37    0.0     False
# 13     Mylena     29    7.0      True
# 14      Lucas     33    0.0     False
# 15      Nadia     34    8.0      True
